# %% [markdown]
# ### Primero tomamos un pdf y extraemos el texto

# %%
import pdfplumber
def extraer_texto_pdf(ruta_pdf):
    texto = "" 
    with pdfplumber.open(ruta_pdf) as pdf:
        for pagina in pdf.pages:
            contenido = pagina.extract_text()
            if contenido: texto += contenido + "\n"
    return texto # Ejemplo de uso
    
ruta = "transformers_teoria.pdf" 
texto = extraer_texto_pdf(ruta)
print(texto)
# Out:
# Redes Neuronales Transformers: Explicación
# Teórica
# Los Transformers son una arquitectura de redes neuronales introducida en 2017 en el artículo
# “Attention is All You Need”.
# Se utilizan principalmente en tareas de procesamiento de lenguaje natural, aunque también se
# aplican en visión y otras áreas.
# A diferencia de modelos anteriores como las redes recurrentes (RNN) o LSTM, los Transformers
# no procesan la información de manera secuencial.
# En su lugar, utilizan un mecanismo llamado “atención” que les permite considerar todas las partes
# de la entrada al mismo tiempo.
# El concepto clave de los Transformers es la atención, específicamente la “self-attention” o
# autoatención.
# Este mecanismo permite que cada palabra en una secuencia evalúe la importancia de las demás
# palabras dentro del mismo contexto.
# Gracias a esto, el modelo puede capturar relaciones a largo plazo sin depender de pasos
# secuenciales.
# La arquitectura básica de un Transformer se compone de dos partes principales: el encoder y el
# decoder.
# El encoder recibe la entrada y genera una representación interna, mientras que el decoder utiliza
# esa representación para producir la salida.
# Cada encoder está formado por múltiples capas idénticas.
# Cada capa contiene dos componentes principales:
# 1) Un mecanismo de autoatención multi-cabeza (multi-head attention).
# 2) Una red neuronal feed-forward completamente conectada.
# La atención multi-cabeza permite al modelo enfocarse en diferentes partes de la secuencia
# simultáneamente.
# Cada “cabeza” aprende distintos tipos de relaciones entre las palabras.
# Además, los Transformers utilizan codificaciones posicionales (positional encoding) para introducir
# información sobre el orden de las palabras.
# Esto es necesario porque el modelo no procesa los datos de manera secuencial.
# El decoder también contiene capas similares al encoder, pero incluye un mecanismo adicional de
# atención que permite enfocarse en la salida del encoder.
# Esto facilita la generación de secuencias, como en traducción automática.
# Otra característica importante es el uso de normalización y conexiones residuales.
# Estas ayudan a estabilizar el entrenamiento y permiten construir modelos más profundos.
# En resumen, los Transformers representan un cambio importante en el diseño de redes
# neuronales.
# Su capacidad para procesar información en paralelo y capturar relaciones complejas los ha
# convertido en la base de muchos modelos modernos de inteligencia artificial.

# %% [markdown]
# ### Separa la letra de la cancion de fondo

# %%
import subprocess
import boto3
import os

archivo = "example3.mp3"
bucket = "music-project-ia"

s3 = boto3.client("s3")

try:
    nombre = os.path.splitext(os.path.basename(archivo))[0]

    # 1. Ejecutar Demucs
    subprocess.run([
        "demucs",
        "--two-stems=vocals",
        archivo
    ], check=True)

    print("Separación completada")

    output_folder = os.path.join("separated", "htdemucs", nombre)

    # 2. Convertir WAV → MP3 antes de subir
    for root, dirs, files in os.walk(output_folder):
        for file in files:

            if file.endswith(".wav"):

                wav_path = os.path.join(root, file)
                mp3_path = wav_path.replace(".wav", ".mp3")

                # convertir con ffmpeg
                subprocess.run([
                    "ffmpeg",
                    "-y",
                    "-i", wav_path,
                    "-b:a", "192k",
                    mp3_path
                ], check=True)

                # subir MP3
                s3_key = f"results/{nombre}/{file.replace('.wav','.mp3')}"

                s3.upload_file(mp3_path, bucket, s3_key)

                print(f"Subido: {mp3_path}")

except Exception as e:
    print("Error:", e)
# Out:
# Separación completada
# Subido: separated\htdemucs\example3\no_vocals.mp3
# Subido: separated\htdemucs\example3\vocals.mp3

# %% [markdown]
# ### Extraer la letra de la cancion

# %%
import boto3
import whisper
import tempfile

s3 = boto3.client("s3")

obj = s3.get_object(
    Bucket="music-project-ia",
    Key="results/example3/vocals.mp3"
)

audio_bytes = obj["Body"].read()

# crear archivo temporal
with tempfile.NamedTemporaryFile(suffix=".mp3", delete=False) as f:
    local_file = f.name
    f.write(audio_bytes)

# cargar modelo
model = whisper.load_model("base")

# TRANSCRIBIR CON SEGMENTOS
result = model.transcribe(
    local_file,
    language="en"
)

# texto completo
letra_original = result["text"]
num_lines = len(result["segments"])
print("LETRA COMPLETA:\n")
print(letra_original)

print("\nSEGMENTOS:\n")

# frases + tiempo
for seg in result["segments"]:

    inicio = seg["start"]
    fin = seg["end"]
    texto = seg["text"]
 
    print(f"Inicio: {inicio:.2f}s")
    print(f"Fin: {fin:.2f}s")
    print(f"Texto: {texto}")
    print("-" * 40)
# Out:
# C:\Users\luigu\anaconda3\envs\MusicaP\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# LETRA COMPLETA:
#
#  I don't hate my job I'm gonna sew your hair I'm gonna get it I'm gonna take it all I'm gonna keep it for you Hey, you know how to do it One best name Hachim, Sub-E-E-L-S-N-E M-M-J Hachim, Hachim, Hachim, Hachim, Hachim, Hachim, Hachim, Hachim, Hachim, Hachim M-M-M-J M-M-M-J Jack, Jack, Jack, Jack, Jack, I'm gonna do it I'm gonna get it when I'm fine, sorry Mia, Nettin' outside Mia, Nettin' inside Prettin' the ones who wanna easily fightgrunts I'm gonna flirt with you I'm gonna flirt with you Ha, I'm gonna flirt with you I'm gonna flirt with you I'm gonna flirt with you I'm gonna flirt with you I'm gonna anyway I'm gonna meet a new man I'm gonna flirt with you He's gonna give it a shit I'm gonnamod your umm I'm gonna be funny with your singer I'm so firey, firey, firey, firey, firey, firey Keep on running, I'm running, I feel like ketchup How you there, how you there, how you there? Another trophy, my hands come to you Not too many that can't even come to you My car, my car My bike, I'm sitting on a nine-hack Somebody's not me, I'm not a pop ball Two beans and you move my body in the end My bike, my bike, my bike Baby watch your mouth, it go back and back Watch your punter, I feel a high slap Color catch on me, bro Same day, close You know how I feel Can't move How many y'all must do it, sir? I keep on trimming the clouds Yeah, I'm on the bumps Yeah, I'm on the bumps Everything we've got in my truck, man Baby, just in my bag, baby Just in my bag, I'm a celebrity Come, I'm a celebrity Come back, I'm a chili butter Watch your punter, I feel a butter I'm a chili butter, I'm a chili butter Color catch on me, bro They'll put you same, no I'm so firey, firey, firey, firey, firey, firey, firey, firey Keep on running, I'm running, I feel like ketchup How you there, how you there? Another trophy, my hands come to you Too many that I can't even come to you Come, come, come Time's right, nothing I'm not Somebody stop it here I've got a pop bar Tell me, is he gonna put my body in there? Come, come, come Time's right, nothing I'm not I'm so firey, firey, firey, firey, firey, firey, firey, firey, firey, firey, firey, firey, firey, fireyigi I keep on trimming the clouds Yeah, I'm on the bumps I'm on the bumps I'm on the bumps I'm on the bumps I'm on the bumps Yeah
#
# SEGMENTOS:
#
# Inicio: 60.00s
# Fin: 64.00s
# Texto:  I don't hate my job I'm gonna sew your hair
# ----------------------------------------
# Inicio: 64.00s
# Fin: 64.80s
# Texto:  I'm gonna get it
# ----------------------------------------
# Inicio: 64.80s
# Fin: 66.90s
# Texto:  I'm gonna take it all
# ----------------------------------------
# Inicio: 66.90s
# Fin: 68.80s
# Texto:  I'm gonna keep it for you
# ----------------------------------------
# Inicio: 68.80s
# Fin: 70.40s
# Texto:  Hey, you know how to do it
# ----------------------------------------
# Inicio: 70.40s
# Fin: 72.00s
# Texto:  One best name
# ----------------------------------------
# Inicio: 72.00s
# Fin: 75.00s
# Texto:  Hachim, Sub-E-E-L-S-N-E
# ----------------------------------------
# Inicio: 75.00s
# Fin: 76.00s
# Texto:  M-M-J
# ----------------------------------------
# Inicio: 76.00s
# Fin: 80.00s
# Texto:  Hachim, Hachim, Hachim, Hachim, Hachim, Hachim, Hachim, Hachim, Hachim, Hachim
# ----------------------------------------
# Inicio: 80.00s
# Fin: 81.40s
# Texto:  M-M-M-J
# ----------------------------------------
# Inicio: 81.40s
# Fin: 82.80s
# Texto:  M-M-M-J
# ----------------------------------------
# Inicio: 82.80s
# Fin: 85.00s
# Texto:  Jack, Jack, Jack, Jack, Jack, I'm gonna do it
# ----------------------------------------
# Inicio: 85.00s
# Fin: 87.00s
# Texto:  I'm gonna get it when I'm fine, sorry
# ----------------------------------------
# Inicio: 87.00s
# Fin: 88.68s
# Texto:  Mia, Nettin' outside
# ----------------------------------------
# Inicio: 88.68s
# Fin: 90.02s
# Texto:  Mia, Nettin' inside
# ----------------------------------------
# Inicio: 90.02s
# Fin: 95.50s
# Texto:  Prettin' the ones who wanna easily fight
# ----------------------------------------
# Inicio: 95.50s
# Fin: 96.52s
# Texto: grunts
# ----------------------------------------
# Inicio: 96.52s
# Fin: 98.52s
# Texto:  I'm gonna flirt with you
# ----------------------------------------
# Inicio: 98.52s
# Fin: 100.26s
# Texto:  I'm gonna flirt with you
# ----------------------------------------
# Inicio: 100.26s
# Fin: 102.00s
# Texto:  Ha, I'm gonna flirt with you
# ----------------------------------------
# Inicio: 102.00s
# Fin: 104.00s
# Texto:  I'm gonna flirt with you
# ----------------------------------------
# Inicio: 106.00s
# Fin: 107.12s
# Texto:  I'm gonna flirt with you
# ----------------------------------------
# Inicio: 107.12s
# Fin: 108.22s
# Texto:  I'm gonna flirt with you
# ----------------------------------------
# Inicio: 108.22s
# Fin: 109.00s
# Texto:  I'm gonna anyway
# ----------------------------------------
# Inicio: 109.00s
# Fin: 110.62s
# Texto:  I'm gonna meet a new man
# ----------------------------------------
# Inicio: 110.62s
# Fin: 112.02s
# Texto:  I'm gonna flirt with you
# ----------------------------------------
# Inicio: 112.02s
# Fin: 114.02s
# Texto:  He's gonna give it a shit
# ----------------------------------------
# Inicio: 114.02s
# Fin: 115.56s
# Texto:  I'm gonnamod your umm
# ----------------------------------------
# Inicio: 115.56s
# Fin: 117.56s
# Texto:  I'm gonna be funny with your singer
# ----------------------------------------
# Inicio: 117.56s
# Fin: 120.40s
# Texto:  I'm so firey, firey, firey, firey, firey, firey
# ----------------------------------------
# Inicio: 120.40s
# Fin: 123.40s
# Texto:  Keep on running, I'm running, I feel like ketchup
# ----------------------------------------
# Inicio: 123.40s
# Fin: 125.96s
# Texto:  How you there, how you there, how you there?
# ----------------------------------------
# Inicio: 125.96s
# Fin: 128.76s
# Texto:  Another trophy, my hands come to you
# ----------------------------------------
# Inicio: 128.76s
# Fin: 132.00s
# Texto:  Not too many that can't even come to you
# ----------------------------------------
# Inicio: 132.00s
# Fin: 134.80s
# Texto:  My car, my car
# ----------------------------------------
# Inicio: 134.80s
# Fin: 137.24s
# Texto:  My bike, I'm sitting on a nine-hack
# ----------------------------------------
# Inicio: 137.24s
# Fin: 140.24s
# Texto:  Somebody's not me, I'm not a pop ball
# ----------------------------------------
# Inicio: 140.24s
# Fin: 143.44s
# Texto:  Two beans and you move my body in the end
# ----------------------------------------
# Inicio: 143.44s
# Fin: 149.24s
# Texto:  My bike, my bike, my bike
# ----------------------------------------
# Inicio: 149.24s
# Fin: 152.04s
# Texto:  Baby watch your mouth, it go back and back
# ----------------------------------------
# Inicio: 152.04s
# Fin: 154.88s
# Texto:  Watch your punter, I feel a high slap
# ----------------------------------------
# Inicio: 154.88s
# Fin: 156.24s
# Texto:  Color catch on me, bro
# ----------------------------------------
# Inicio: 156.24s
# Fin: 157.76s
# Texto:  Same day, close
# ----------------------------------------
# Inicio: 157.76s
# Fin: 159.12s
# Texto:  You know how I feel
# ----------------------------------------
# Inicio: 159.12s
# Fin: 161.44s
# Texto:  Can't move
# ----------------------------------------
# Inicio: 161.44s
# Fin: 164.16s
# Texto:  How many y'all must do it, sir?
# ----------------------------------------
# Inicio: 164.16s
# Fin: 166.16s
# Texto:  I keep on trimming the clouds
# ----------------------------------------
# Inicio: 166.16s
# Fin: 167.48s
# Texto:  Yeah, I'm on the bumps
# ----------------------------------------
# Inicio: 167.48s
# Fin: 169.00s
# Texto:  Yeah, I'm on the bumps
# ----------------------------------------
# Inicio: 169.00s
# Fin: 171.80s
# Texto:  Everything we've got in my truck, man
# ----------------------------------------
# Inicio: 171.80s
# Fin: 173.36s
# Texto:  Baby, just in my bag, baby
# ----------------------------------------
# Inicio: 173.36s
# Fin: 175.04s
# Texto:  Just in my bag, I'm a celebrity
# ----------------------------------------
# Inicio: 175.04s
# Fin: 176.52s
# Texto:  Come, I'm a celebrity
# ----------------------------------------
# Inicio: 176.52s
# Fin: 178.64s
# Texto:  Come back, I'm a chili butter
# ----------------------------------------
# Inicio: 178.64s
# Fin: 180.64s
# Texto:  Watch your punter, I feel a butter
# ----------------------------------------
# Inicio: 180.64s
# Fin: 182.84s
# Texto:  I'm a chili butter, I'm a chili butter
# ----------------------------------------
# Inicio: 182.84s
# Fin: 184.08s
# Texto:  Color catch on me, bro
# ----------------------------------------
# Inicio: 184.08s
# Fin: 185.64s
# Texto:  They'll put you same, no
# ----------------------------------------
# Inicio: 185.64s
# Fin: 188.32s
# Texto:  I'm so firey, firey, firey, firey, firey, firey, firey, firey
# ----------------------------------------
# Inicio: 188.32s
# Fin: 191.28s
# Texto:  Keep on running, I'm running, I feel like ketchup
# ----------------------------------------
# Inicio: 191.28s
# Fin: 193.76s
# Texto:  How you there, how you there?
# ----------------------------------------
# Inicio: 193.76s
# Fin: 197.04s
# Texto:  Another trophy, my hands come to you
# ----------------------------------------
# Inicio: 197.04s
# Fin: 199.60s
# Texto:  Too many that I can't even come to you
# ----------------------------------------
# Inicio: 199.96s
# Fin: 201.96s
# Texto:  Come, come, come
# ----------------------------------------
# Inicio: 201.96s
# Fin: 204.92s
# Texto:  Time's right, nothing I'm not
# ----------------------------------------
# Inicio: 204.92s
# Fin: 206.52s
# Texto:  Somebody stop it here
# ----------------------------------------
# Inicio: 206.52s
# Fin: 207.92s
# Texto:  I've got a pop bar
# ----------------------------------------
# Inicio: 207.92s
# Fin: 210.76s
# Texto:  Tell me, is he gonna put my body in there?
# ----------------------------------------
# Inicio: 210.76s
# Fin: 213.36s
# Texto:  Come, come, come
# ----------------------------------------
# Inicio: 213.36s
# Fin: 216.76s
# Texto:  Time's right, nothing I'm not
# ----------------------------------------
# Inicio: 216.76s
# Fin: 223.24s
# Texto:  I'm so firey, firey, firey, firey, firey, firey, firey, firey, firey, firey, firey, firey, firey, fireyigi
# ----------------------------------------
# Inicio: 223.24s
# Fin: 224.80s
# Texto:  I keep on trimming the clouds
# ----------------------------------------
# Inicio: 224.80s
# Fin: 227.44s
# Texto:  Yeah, I'm on the bumps
# ----------------------------------------
# Inicio: 257.44s
# Fin: 258.84s
# Texto:  I'm on the bumps
# ----------------------------------------
# Inicio: 258.84s
# Fin: 260.24s
# Texto:  I'm on the bumps
# ----------------------------------------
# Inicio: 260.24s
# Fin: 260.72s
# Texto:  I'm on the bumps
# ----------------------------------------
# Inicio: 260.72s
# Fin: 261.72s
# Texto:  I'm on the bumps
# ----------------------------------------
# Inicio: 261.72s
# Fin: 262.72s
# Texto:  Yeah
# ----------------------------------------

# %% [markdown]
# ### Crear la letra con LLM

# %%
import boto3
from botocore.exceptions import ClientError

def llamar_qwen(prompt):

    client = boto3.client("bedrock-runtime", region_name="us-east-1")

    # 2. Definir el ID del modelo Qwen
    # Ejemplo para Qwen 2.5 72B Instruct (verifica la versión exacta en tu catálogo)
    model_id = "google.gemma-3-12b-it"

    # 3. Preparar el mensaje
    messages = [
        {
            "role": "user",
            "content": [{"text": prompt}]
        }
    ]

    try:
        # 4. Realizar la llamada usando la Converse API
        response = client.converse(
            modelId=model_id,
            messages=messages,
            inferenceConfig={
                "maxTokens": 1000,
                "temperature": 0.7,
                "topP": 0.9
            }
        )

        # 5. Extraer y retornar el texto
        return response['output']['message']['content'][0]['text']

    except ClientError as e:
        return f"Error de cliente: {e}"
    except Exception as e:
        return f"Error inesperado: {e}"
        
# Asegúrate de que estas variables tengan contenido real
prompt = f"""
SISTEMA: Eres un extractor de datos técnicos. 
Tu objetivo es tomar la INFORMACIÓN del PDF y darle el ritmo de la ESTRUCTURA sugerida.

[DATOS TÉCNICOS DEL PDF]
{texto}

[ESTRUCTURA RÍTMICA A SEGUIR]
{letra_original}

[REGLAS CRÍTICAS]
- PROHIBIDO: No uses ninguna palabra de la 'ESTRUCTURA RÍTMICA'. 
- OBLIGATORIO: Solo usa conceptos encontrados en el 'DATOS TÉCNICOS DEL PDF'.
- Si mencionas "Stressed out", "Mama", "Sleep" o "Time", la tarea fallará.
- Genera exactamente {num_lines} líneas.
- No saludes, no expliques, solo entrega la letra educativa.

RESULTADO (CANCIÓN TÉCNICA):
"""

# --- Ejemplo de uso ---
if __name__ == "__main__":
    pregunta =  prompt 
    resultado = llamar_qwen(pregunta)
    print("Respuesta:\n", resultado)
# Out:
# Respuesta:
#  Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah
#
# Yeah

# %% [markdown]
# ### Clonar voz

# %%
import boto3
from TTS.api import TTS

BUCKET = "music-project-ia"
KEY = "results/example2/vocals.mp3"
LOCAL_AUDIO = "voz.mp3"

generated_lines = [
    x.strip()
    for x in resultado.split("\n")
    if x.strip()
]
s3 = boto3.client("s3")
s3.download_file(BUCKET, KEY, LOCAL_AUDIO)

tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2")

for i, line in enumerate(generated_lines):

    print(f"Generando línea {i}: {line}")

    tts.tts_to_file(
        text=line,
        speaker_wav=LOCAL_AUDIO,
        language="es",
        file_path=f"line_{i}.wav"
    )
# Out:
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
# Generando línea 0: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.634442329406738
#  > Real-time factor: 3.5305919487084916
# Generando línea 1: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 7.279152154922485
#  > Real-time factor: 2.579475845590782
# Generando línea 2: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 5.782609701156616
#  > Real-time factor: 2.9460846559728138
# Generando línea 3: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 5.957804203033447
#  > Real-time factor: 2.7432672627148245
# Generando línea 4: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.021511793136597
#  > Real-time factor: 3.6437514397872275
# Generando línea 5: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.299992084503174
#  > Real-time factor: 3.4273722333464067
# Generando línea 6: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.38972282409668
#  > Real-time factor: 3.3441607335313637
# Generando línea 7: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 6.5880286693573
#  > Real-time factor: 2.6142029973964953
# Generando línea 8: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 5.207423210144043
#  > Real-time factor: 2.949642462589297
# Generando línea 9: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.326359033584595
#  > Real-time factor: 3.448388399744806
# Generando línea 10: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 7.164956569671631
#  > Real-time factor: 2.581491705249338
# Generando línea 11: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 21.902095079421997
#  > Real-time factor: 2.19088515506485
# Generando línea 12: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 5.739583492279053
#  > Real-time factor: 2.7763648649691364
# Generando línea 13: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.657907009124756
#  > Real-time factor: 3.182537479895912
# Generando línea 14: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 10.680076599121094
#  > Real-time factor: 2.4077344287851723
# Generando línea 15: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 5.791233539581299
#  > Real-time factor: 2.8013491476783
# Generando línea 16: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.376363039016724
#  > Real-time factor: 3.3339830365643572
# Generando línea 17: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 6.463242292404175
#  > Real-time factor: 2.7826166148764457
# Generando línea 18: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 6.964593410491943
#  > Real-time factor: 2.6536025141924826
# Generando línea 19: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.10677170753479
#  > Real-time factor: 3.7210024716938745
# Generando línea 20: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 10.726020812988281
#  > Real-time factor: 2.33261755292717
# Generando línea 21: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 6.832951307296753
#  > Real-time factor: 2.6623299463862984
# Generando línea 22: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 6.069870948791504
#  > Real-time factor: 2.8716240649856815
# Generando línea 23: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 5.743061065673828
#  > Real-time factor: 3.1696660116666977
# Generando línea 24: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.895017385482788
#  > Real-time factor: 3.482677250577422
# Generando línea 25: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 4.433122158050537
#  > Real-time factor: 3.6693071916296676
# Generando línea 26: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 6.843668222427368
#  > Real-time factor: 3.2377034909140803
# Generando línea 27: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 8.943249702453613
#  > Real-time factor: 3.484567711674833
# Generando línea 28: Yeah
#  > Text splitted to sentences.
# ['Yeah']
#  > Processing time: 5.710786819458008
#  > Real-time factor: 4.350568317062226
# Generando línea 29: Yeah
#  > Text splitted to sentences.
# ['Yeah']

# %%
import boto3
from pydub import AudioSegment
import tempfile

# =========================
# S3 CONFIG
# =========================
s3 = boto3.client("s3")

BUCKET = "music-project-ia"
INSTRUMENTAL_KEY = "results/example3/no_vocals.mp3"

# =========================
# DESCARGAR INSTRUMENTAL
# =========================
with tempfile.NamedTemporaryFile(suffix=".mp3", delete=False) as tmp:
    instrumental_path = tmp.name

s3.download_file(BUCKET, INSTRUMENTAL_KEY, instrumental_path)
print("Instrumental descargada desde S3")

# =========================
# CARGAR AUDIO
# =========================
instrumental = AudioSegment.from_mp3(instrumental_path)
instrumental = instrumental - 8  # bajar volumen del beat

final = instrumental

# =========================
# MEZCLA CON VOCES
# =========================
max_len = min(len(result["segments"]), len(generated_lines))

for i in range(max_len):

    try:
        voice = AudioSegment.from_wav(f"line_{i}.wav")

        voice = voice + 5  # subir voz

        start_ms = int(result["segments"][i]["start"] * 1000)

        print(f"Overlay línea {i} en {start_ms} ms")

        final = final.overlay(
            voice,
            position=start_ms
        )

    except Exception as e:
        print(f"Error línea {i}: {e}")

# =========================
# EXPORT FINAL
# =========================
final.export("cancion_final.mp3", format="mp3")

print("✅ listo")
# Out:
# Instrumental descargada desde S3
# Overlay línea 0 en 90000 ms
# Overlay línea 1 en 93000 ms
# Overlay línea 2 en 95000 ms
# Overlay línea 3 en 98000 ms
# Overlay línea 4 en 101000 ms
# Overlay línea 5 en 104000 ms
# Overlay línea 6 en 107000 ms
# Overlay línea 7 en 109000 ms
# Overlay línea 8 en 112000 ms
# Overlay línea 9 en 115000 ms
# Overlay línea 10 en 118000 ms
# Overlay línea 11 en 120000 ms
# Overlay línea 12 en 123000 ms
# Overlay línea 13 en 126000 ms
# Overlay línea 14 en 129000 ms
# Overlay línea 15 en 132000 ms
# Overlay línea 16 en 135000 ms
# Overlay línea 17 en 137000 ms
# Overlay línea 18 en 140000 ms
# Overlay línea 19 en 143000 ms
# Overlay línea 20 en 146000 ms
# Overlay línea 21 en 150000 ms
# Overlay línea 22 en 153000 ms
# Overlay línea 23 en 156000 ms
# Overlay línea 24 en 160000 ms
# Overlay línea 25 en 166000 ms
# Overlay línea 26 en 169000 ms
# Overlay línea 27 en 172000 ms
# Overlay línea 28 en 174000 ms
# Overlay línea 29 en 177000 ms
# Overlay línea 30 en 180000 ms
# Overlay línea 31 en 182000 ms
# Overlay línea 32 en 185000 ms
# Overlay línea 33 en 188000 ms
# Overlay línea 34 en 191000 ms
# Overlay línea 35 en 194000 ms
# Overlay línea 36 en 197000 ms
# Overlay línea 37 en 200000 ms
# Overlay línea 38 en 202000 ms
# Overlay línea 39 en 206000 ms
# Overlay línea 40 en 210000 ms
# Overlay línea 41 en 213000 ms
# Overlay línea 42 en 218000 ms
# Overlay línea 43 en 221000 ms
# Overlay línea 44 en 223000 ms
# Overlay línea 45 en 227000 ms
# Overlay línea 46 en 231000 ms
# Overlay línea 47 en 236000 ms
# Overlay línea 48 en 239000 ms
# Overlay línea 49 en 242000 ms
# Overlay línea 50 en 248000 ms
# Overlay línea 51 en 251000 ms
# ✅ listo

# %%
##Todo

# %%
import pdfplumber
def extraer_texto_pdf(ruta_pdf):
    texto = "" 
    with pdfplumber.open(ruta_pdf) as pdf:
        for pagina in pdf.pages:
            contenido = pagina.extract_text()
            if contenido: texto += contenido + "\n"
    return texto # Ejemplo de uso
    
ruta = "topologia_explicacion.pdf" 
texto = extraer_texto_pdf(ruta)
print(texto)

import subprocess
import boto3
import os

archivo = "example3.mp3"
bucket = "music-project-ia"

s3 = boto3.client("s3")

try:
    nombre = os.path.splitext(os.path.basename(archivo))[0]

    # 1. Ejecutar Demucs
    subprocess.run([
        "demucs",
        "--two-stems=vocals",
        archivo
    ], check=True)

    print("Separación completada")

    output_folder = os.path.join("separated", "htdemucs", nombre)

    # 2. Convertir WAV → MP3 antes de subir
    for root, dirs, files in os.walk(output_folder):
        for file in files:

            if file.endswith(".wav"):

                wav_path = os.path.join(root, file)
                mp3_path = wav_path.replace(".wav", ".mp3")

                # convertir con ffmpeg
                subprocess.run([
                    "ffmpeg",
                    "-y",
                    "-i", wav_path,
                    "-b:a", "192k",
                    mp3_path
                ], check=True)

                # subir MP3
                s3_key = f"results/{nombre}/{file.replace('.wav','.mp3')}"

                s3.upload_file(mp3_path, bucket, s3_key)

                print(f"Subido: {mp3_path}")

except Exception as e:
    print("Error:", e)

import boto3
import whisper
import tempfile

s3 = boto3.client("s3")

obj = s3.get_object(
    Bucket="music-project-ia",
    Key="results/example3/vocals.mp3"
)

audio_bytes = obj["Body"].read()

# crear archivo temporal
with tempfile.NamedTemporaryFile(suffix=".mp3", delete=False) as f:
    local_file = f.name
    f.write(audio_bytes)

# cargar modelo
model = whisper.load_model("base")

# TRANSCRIBIR CON SEGMENTOS
result = model.transcribe(
    local_file,
    language="en"
)

# texto completo
letra_original = result["text"]
num_lines = len(result["segments"])
print("LETRA COMPLETA:\n")
print(letra_original)

print("\nSEGMENTOS:\n")

# frases + tiempo
for seg in result["segments"]:

    inicio = seg["start"]
    fin = seg["end"]
    texto = seg["text"]
 
    print(f"Inicio: {inicio:.2f}s")
    print(f"Fin: {fin:.2f}s")
    print(f"Texto: {texto}")
    print("-" * 40)
import boto3
from botocore.exceptions import ClientError

def llamar_qwen(prompt):

    client = boto3.client("bedrock-runtime", region_name="us-east-1")

    # 2. Definir el ID del modelo Qwen
    # Ejemplo para Qwen 2.5 72B Instruct (verifica la versión exacta en tu catálogo)
    model_id = "google.gemma-3-12b-it"

    # 3. Preparar el mensaje
    messages = [
        {
            "role": "user",
            "content": [{"text": prompt}]
        }
    ]

    try:
        # 4. Realizar la llamada usando la Converse API
        response = client.converse(
            modelId=model_id,
            messages=messages,
            inferenceConfig={
                "maxTokens": 1000,
                "temperature": 0.7,
                "topP": 0.9
            }
        )

        # 5. Extraer y retornar el texto
        return response['output']['message']['content'][0]['text']

    except ClientError as e:
        return f"Error de cliente: {e}"
    except Exception as e:
        return f"Error inesperado: {e}"
        
# Asegúrate de que estas variables tengan contenido real
prompt = f"""
SISTEMA: Eres un extractor de datos técnicos. 
Tu objetivo es tomar la INFORMACIÓN del PDF y darle el ritmo de la ESTRUCTURA sugerida.

[DATOS TÉCNICOS DEL PDF]
{texto}

[ESTRUCTURA RÍTMICA A SEGUIR]
{letra_original}

[REGLAS CRÍTICAS]
- PROHIBIDO: No uses ninguna palabra de la 'ESTRUCTURA RÍTMICA'. 
- OBLIGATORIO: Solo usa conceptos encontrados en el 'DATOS TÉCNICOS DEL PDF'.
- Si mencionas "Stressed out", "Mama", "Sleep" o "Time", la tarea fallará.
- Genera exactamente {num_lines} líneas.
- No saludes, no expliques, solo entrega la letra educativa.

RESULTADO (CANCIÓN TÉCNICA):
"""

# --- Ejemplo de uso ---
if __name__ == "__main__":
    pregunta =  prompt 
    resultado = llamar_qwen(pregunta)
    print("Respuesta:\n", resultado)

import boto3
from TTS.api import TTS

BUCKET = "music-project-ia"
KEY = "results/example2/vocals.mp3"
LOCAL_AUDIO = "voz.mp3"

generated_lines = [
    x.strip()
    for x in resultado.split("\n")
    if x.strip()
]
s3 = boto3.client("s3")
s3.download_file(BUCKET, KEY, LOCAL_AUDIO)

tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2")

for i, line in enumerate(generated_lines):

    print(f"Generando línea {i}: {line}")

    tts.tts_to_file(
        text=line,
        speaker_wav=LOCAL_AUDIO,
        language="es",
        file_path=f"line_{i}.wav"
    )
import boto3
from pydub import AudioSegment
import tempfile

# =========================
# S3 CONFIG
# =========================
s3 = boto3.client("s3")

BUCKET = "music-project-ia"
INSTRUMENTAL_KEY = "results/example3/no_vocals.mp3"

# =========================
# DESCARGAR INSTRUMENTAL
# =========================
with tempfile.NamedTemporaryFile(suffix=".mp3", delete=False) as tmp:
    instrumental_path = tmp.name

s3.download_file(BUCKET, INSTRUMENTAL_KEY, instrumental_path)
print("Instrumental descargada desde S3")

# =========================
# CARGAR AUDIO
# =========================
instrumental = AudioSegment.from_mp3(instrumental_path)
instrumental = instrumental - 8  # bajar volumen del beat

final = instrumental

# =========================
# MEZCLA CON VOCES
# =========================
max_len = min(len(result["segments"]), len(generated_lines))

for i in range(max_len):

    try:
        voice = AudioSegment.from_wav(f"line_{i}.wav")

        voice = voice + 5  # subir voz

        start_ms = int(result["segments"][i]["start"] * 1000)

        print(f"Overlay línea {i} en {start_ms} ms")

        final = final.overlay(
            voice,
            position=start_ms
        )

    except Exception as e:
        print(f"Error línea {i}: {e}")

# =========================
# EXPORT FINAL
# =========================
final.export("cancion_final.mp3", format="mp3")

print("✅ listo")
